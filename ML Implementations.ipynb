# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\Mastan\\anaconda3\\envs\\task\\python.exe'

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/Mastan/Downloads/archive (1)/Salary Data.csv',header=0)

# %%
df.head(10)
# Out:
#     Age  Gender Education Level              Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's      Software Engineer                  5.0
# 1  28.0  Female        Master's           Data Analyst                  3.0
# 2  45.0    Male             PhD         Senior Manager                 15.0
# 3  36.0  Female      Bachelor's        Sales Associate                  7.0
# 4  52.0    Male        Master's               Director                 20.0
# 5  29.0    Male      Bachelor's      Marketing Analyst                  2.0
# 6  42.0  Female        Master's        Product Manager                 12.0
# 7  31.0    Male      Bachelor's          Sales Manager                  4.0
# 8  26.0  Female      Bachelor's  Marketing Coordinator                  1.0
# 9  38.0    Male             PhD       Senior Scientist                 10.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0
# 5   55000.0
# 6  120000.0
# 7   80000.0
# ...

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
df.dropna()
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %% [markdown]
# Here Job Title as so many unique values so its better to remove "Job Title" column. Which doesn't have any importance

# %%
df = df.drop(columns=['Job Title'])

# %%
df
# Out:
#       Age  Gender Education Level  Years of Experience    Salary
# 0    32.0    Male      Bachelor's                  5.0   90000.0
# 1    28.0  Female        Master's                  3.0   65000.0
# 2    45.0    Male             PhD                 15.0  150000.0
# 3    36.0  Female      Bachelor's                  7.0   60000.0
# 4    52.0    Male        Master's                 20.0  200000.0
# ..    ...     ...             ...                  ...       ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0
# 371  43.0    Male        Master's                 19.0  170000.0
# 372  29.0  Female      Bachelor's                  2.0   40000.0
# 373  34.0    Male      Bachelor's                  7.0   90000.0
# 374  44.0  Female             PhD                 15.0  150000.0
#
# [375 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
df=df.dropna()

# %%
pd.get_dummies(df, columns=['Gender'], drop_first=True)
# Out:
#       Age Education Level  Years of Experience    Salary  Gender_Male
# 0    32.0      Bachelor's                  5.0   90000.0         True
# 1    28.0        Master's                  3.0   65000.0        False
# 2    45.0             PhD                 15.0  150000.0         True
# 3    36.0      Bachelor's                  7.0   60000.0        False
# 4    52.0        Master's                 20.0  200000.0         True
# ..    ...             ...                  ...       ...          ...
# 370  35.0      Bachelor's                  8.0   85000.0        False
# 371  43.0        Master's                 19.0  170000.0         True
# 372  29.0      Bachelor's                  2.0   40000.0        False
# 373  34.0      Bachelor's                  7.0   90000.0         True
# 374  44.0             PhD                 15.0  150000.0        False
#
# [373 rows x 5 columns]

# %%
df['Education Level'].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD'], dtype=object)

# %% [markdown]
# #### OneHotEncoding

# %%
    from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Education Level']=le.fit_transform(df['Education Level'])
# Out:
# C:\Users\Mastan\AppData\Local\Temp\ipykernel_3048\1883406878.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Education Level']=le.fit_transform(df['Education Level'])

# %%
df
# Out:
#       Age  Gender  Education Level  Years of Experience    Salary
# 0    32.0    Male                0                  5.0   90000.0
# 1    28.0  Female                1                  3.0   65000.0
# 2    45.0    Male                2                 15.0  150000.0
# 3    36.0  Female                0                  7.0   60000.0
# 4    52.0    Male                1                 20.0  200000.0
# ..    ...     ...              ...                  ...       ...
# 370  35.0  Female                0                  8.0   85000.0
# 371  43.0    Male                1                 19.0  170000.0
# 372  29.0  Female                0                  2.0   40000.0
# 373  34.0    Male                0                  7.0   90000.0
# 374  44.0  Female                2                 15.0  150000.0
#
# [373 rows x 5 columns]

# %%
df.head()
# Out:
#     Age  Gender  Education Level  Years of Experience    Salary
# 0  32.0    Male                0                  5.0   90000.0
# 1  28.0  Female                1                  3.0   65000.0
# 2  45.0    Male                2                 15.0  150000.0
# 3  36.0  Female                0                  7.0   60000.0
# 4  52.0    Male                1                 20.0  200000.0

# %%
df=pd.get_dummies(df, columns=['Gender'], drop_first=True)

# %%
df
# Out:
#       Age  Education Level  Years of Experience    Salary  Gender_Male
# 0    32.0                0                  5.0   90000.0         True
# 1    28.0                1                  3.0   65000.0        False
# 2    45.0                2                 15.0  150000.0         True
# 3    36.0                0                  7.0   60000.0        False
# 4    52.0                1                 20.0  200000.0         True
# ..    ...              ...                  ...       ...          ...
# 370  35.0                0                  8.0   85000.0        False
# 371  43.0                1                 19.0  170000.0         True
# 372  29.0                0                  2.0   40000.0        False
# 373  34.0                0                  7.0   90000.0         True
# 374  44.0                2                 15.0  150000.0        False
#
# [373 rows x 5 columns]

# %%
df.head(10)
# Out:
#     Age  Education Level  Years of Experience    Salary  Gender_Male
# 0  32.0                0                  5.0   90000.0         True
# 1  28.0                1                  3.0   65000.0        False
# 2  45.0                2                 15.0  150000.0         True
# 3  36.0                0                  7.0   60000.0        False
# 4  52.0                1                 20.0  200000.0         True
# 5  29.0                0                  2.0   55000.0         True
# 6  42.0                1                 12.0  120000.0        False
# 7  31.0                0                  4.0   80000.0         True
# 8  26.0                0                  1.0   45000.0        False
# 9  38.0                2                 10.0  110000.0         True

# %% [markdown]
# #### The response varaible is salary(Y) and remaming all are independent varaibles(X)

# %%
dfcor=df.corr()

# %%
plt.figure(figsize=(8, 6))  # Adjust the size of the heatmap
sns.heatmap(dfcor, annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
X = df.drop('Salary', axis=1)
Y = df['Salary']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %% [markdown]
# ## Linear Regression

# %%
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
mse=mean_squared_error(Y_test,y_pred)

# %%
print(mse)
# Out:
# 232595028.52964896

# %% [markdown]
# ## Support Vector Regressor

# %%
from sklearn.svm import SVR

# %%
model1=SVR(kernel='rbf')

# %%
model1.fit(X_train,Y_train)
# Out:
# SVR()

# %%
y_pred1=model1.predict(X_test)

# %%
mse1=mean_squared_error(Y_test,y_pred1)

# %%
print(mse1)
# Out:
# 2450382732.1167674

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RFR=RandomForestRegressor(n_estimators=1000,random_state=42)

# %%
RFR.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=42)

# %%
y_pred2=RFR.predict(X_test)

# %%
mse2=mean_squared_error(Y_test,y_pred2)

# %%
print(mse2)
# Out:
# 265405445.9437823

# %% [markdown]
# ### Decision Trees Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
DTR=DecisionTreeRegressor(random_state=42)

# %%
DTR.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
y_pred3=DTR.predict(X_test)

# %%
mse3=mean_squared_error(Y_test,y_pred3)

# %%
print(mse3)
# Out:
# 231101568.40513983

# %% [markdown]
# ### Rigde and Lasso regression

# %%
from sklearn.linear_model import Ridge, Lasso

# %%
R=Ridge(alpha=1.0)

# %%
R.fit(X_train,Y_train)
# Out:
# Ridge()

# %%
y_pred4=R.predict(X_test)

# %%
mse4=mean_squared_error(Y_test,y_pred4)

# %%
print(mse4)
# Out:
# 231962938.97639093

# %%
L=Lasso(alpha=1.0)

# %%
L.fit(X_train,Y_train)
# Out:
# Lasso()

# %%
y_pred5=L.predict(X_test)

# %%
mse5=mean_squared_error(Y_test,y_pred5)

# %%
print(mse5)
# Out:
# 232607075.59610656
